# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('my_model')
tflite_model = converter.convert()

with open('classify.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/object_detection/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:4177, in Graph._get_op_def(self, type)
#    4176 try:
# -> 4177   return self._op_def_cache[type]
#    4178 except KeyError:
#
# KeyError: 'DisableCopyOnRead'
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# File ~/anaconda3/envs/object_detection/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py:974, in load_internal(export_dir, tags, options, loader_cls, filters)
#     973 try:
# --> 974   loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
#     975                       ckpt_options, options, filters)
#     976 except errors.NotFoundError as err:
#
# ...
