# %%
import os

# Path to the folder
folder_path = 'face skin type/oily'

# List all files
files = os.listdir(folder_path)
files.sort()  # Optional: to ensure consistent order

# Rename
for i, filename in enumerate(files):
    ext = os.path.splitext(filename)[1]  # Get file extension
    new_name = f'image_{i+2192:03d}{ext}'   # e.g., image_001.jpg
    old_path = os.path.join(folder_path, filename)
    new_path = os.path.join(folder_path, new_name)
    os.rename(old_path, new_path)

print("Files renamed successfully.")
# Out:
# Files renamed successfully.

# %%
import os
import pandas as pd

# === Configuration ===
folder_path = 'face skin type/oily'  # Folder containing renamed files
label = 'oily'                       # Label for this folder
csv_path = 'multi_label_dataset.csv'  # Output CSV

# === Get renamed files ===
files = os.listdir(folder_path)
files.sort()  # Ensure order matches rename

# === Create DataFrame with filenames and label ===
data = []
for filename in files:
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        data.append({'filename': filename, 'label': label})

df_new = pd.DataFrame(data)

# === Check if CSV already exists ===
if os.path.exists(csv_path):
    df_existing = pd.read_csv(csv_path)
    df_combined = pd.concat([df_existing, df_new], ignore_index=True)
    df_combined.to_csv(csv_path, index=False)
    print(f"Appended to existing {csv_path}")
else:
    df_new.to_csv(csv_path, index=False)
    print(f"Created new {csv_path}")
# Out:
# Appended to existing multi_label_dataset.csv

# %% [markdown]
# # Face Crop

# %%
import cv2
import os

input_folder = 'face skin type/oily'
output_folder = 'dataset/oily'
os.makedirs(output_folder, exist_ok=True)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(input_folder, filename)
        img = cv2.imread(image_path)
        if img is None:
            continue
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.1, 4)

        if len(faces) == 0:
            print(f"No face in {filename}")
            continue

        for (x, y, w, h) in faces:
            face_crop = img[y:y+h, x:x+w]
            cv2.imwrite(os.path.join(output_folder, filename), face_crop)
            break  # only save the first detected face
# Out:
# No face in image_2203.jpg
# No face in image_2277.jpg
# No face in image_2512.jpg
# No face in image_2565.jpg
# No face in image_2669.jpg
# No face in image_2421.jpg
# No face in image_2811.jpg
# No face in image_2280.jpg
# No face in image_2201.jpg
# No face in image_2555.jpg
# No face in image_2774.jpg
# No face in image_2523.jpg
# No face in image_2577.jpg
# No face in image_2311.jpg
# No face in image_2602.jpg
# No face in image_2489.jpg
# No face in image_2506.jpg
# No face in image_2322.jpg
# No face in image_2430.jpg
# No face in image_2510.jpg
# No face in image_2504.jpg
# No face in image_2784.jpg
# No face in image_2529.jpg
# No face in image_2509.jpg
# No face in image_2387.jpg
# No face in image_2295.jpg
# No face in image_2193.jpg
# No face in image_2469.jpg
# No face in image_2792.jpg
# No face in image_2712.jpg
# No face in image_2670.jpg
# No face in image_2716.jpg
# No face in image_2337.jpg
# No face in image_2328.jpg
# No face in image_2424.jpg
# No face in image_2233.jpg
# No face in image_2382.jpg
# No face in image_2462.jpg
# No face in image_2394.jpg
# No face in image_2314.jpg
# No face in image_2636.jpg
# No face in image_2747.jpg
# No face in image_2778.jpeg
# No face in image_2238.jpg
# No face in image_2664.jpg
# No face in image_2434.jpg
# No face in image_2308.jpg
# No face in image_2249.jpg
# No face in image_2225.jpg
# No face in image_2224.jpg
# No face in image_2771.jpg
# No face in image_2547.jpg
# No face in image_2398.jpg
# No face in image_2226.jpg
# No face in image_2797.jpg
# No face in image_2237.jpg
# No face in image_2448.jpg
# No face in image_2369.jpg
# No face in image_2812.jpg
# No face in image_2284.jpg
# No face in image_2479.jpg
# No face in image_2340.jpg
# No face in image_2681.jpg
# No face in image_2787.jpg
# No face in image_2751.jpg
# No face in image_2402.jpg
# No face in image_2502.jpg
# No face in image_2739.jpg
# No face in image_2508.jpg
# No face in image_2455.jpg
# No face in image_2367.jpg
# No face in image_2230.jpeg
# No face in image_2609.jpg
# No face in image_2330.jpg
# No face in image_2273.jpg
# No face in image_2419.jpg
# No face in image_2447.jpg
# No face in image_2500.jpg
# No face in image_2272.jpg
# No face in image_2468.jpg
# No face in image_2470.jpg
# No face in image_2268.jpg
# No face in image_2546.jpg
# No face in image_2269.jpg
# No face in image_2217.jpg
# No face in image_2350.jpg
# No face in image_2693.jpg
# No face in image_2453.jpg
# No face in image_2375.jpg
# No face in image_2802.jpeg
# No face in image_2474.jpg
# No face in image_2776.jpg
# No face in image_2478.jpg
# No face in image_2244.jpg
# No face in image_2446.jpg
# No face in image_2251.jpg
# No face in image_2791.jpg
# No face in image_2785.jpg
# No face in image_2405.jpg
# No face in image_2370.jpg
# No face in image_2642.jpg
# No face in image_2327.jpg
# No face in image_2196.jpg
# No face in image_2319.jpg
# No face in image_2449.jpg
# No face in image_2339.jpg
# No face in image_2804.jpg
# No face in image_2494.jpg
# No face in image_2303.jpg
# No face in image_2497.jpg
# No face in image_2779.jpg
# No face in image_2487.jpg
# No face in image_2276.jpg
# No face in image_2499.jpg
# No face in image_2254.jpg
# No face in image_2321.jpg
# No face in image_2744.jpg
# No face in image_2285.jpg
# No face in image_2378.jpg
# No face in image_2736.jpg
# No face in image_2503.jpg
# No face in image_2573.jpg
# No face in image_2216.jpg
# No face in image_2505.jpg
# No face in image_2351.jpg
# No face in image_2516.jpg
# No face in image_2333.jpg
# No face in image_2409.jpg
# No face in image_2357.jpg
# No face in image_2551.jpg
# No face in image_2532.jpg
# No face in image_2492.jpg
# No face in image_2683.jpg
# No face in image_2365.jpg
# No face in image_2456.jpg
# No face in image_2299.jpg
# No face in image_2640.jpg
# No face in image_2481.jpg
# No face in image_2200.jpg
# No face in image_2798.jpg

# %%
import os
import shutil

# Define folders
folder1 = 'face skin type/oily'     # e.g., face skin type/acne
folder2 = 'dataset/oily'  # e.g., cropped_faces/acne

# Make sure destination exists
os.makedirs(folder2, exist_ok=True)

# List files in both folders
source_files = os.listdir(folder1)
dest_files = set(os.listdir(folder2))  # use set for fast lookup

# Copy missing files
copied = 0
for file in source_files:
    if file.lower().endswith(('.jpg', '.jpeg', '.png')) and file not in dest_files:
        src_path = os.path.join(folder1, file)
        dst_path = os.path.join(folder2, file)
        shutil.copy2(src_path, dst_path)
        copied += 1

print(f"✅ Copied {copied} missing files from '{folder1}' to '{folder2}'.")
# Out:
# ✅ Copied 64 missing files from 'face skin type/oily' to 'dataset/oily'.

# %% [markdown]
# # Object Detection

# %%
import os
import shutil

# Define folders
folder1 = 'dataset_object_detection/annotations'  # contains .xml
folder2 = 'dataset_object_detection/images'       # destination for .jpg/.png
folder3 = 'dataset'                                # contains source images

# Make sure destination exists
os.makedirs(folder2, exist_ok=True)

# List files
xml_files = [f for f in os.listdir(folder1) if f.lower().endswith('.xml')]
image_extensions = ['.jpg', '.jpeg', '.png']

copied = 0

for xml_file in xml_files:
    base_name = os.path.splitext(xml_file)[0]  # e.g., file1 from file1.xml

    # Try to find a matching image in folder3
    for ext in image_extensions:
        image_file = base_name + ext
        src_img_path = os.path.join(folder3, image_file)
        dst_img_path = os.path.join(folder2, image_file)

        if os.path.exists(src_img_path):
            shutil.copy2(src_img_path, dst_img_path)
            copied += 1
            print(f"✅ Copied {image_file}")
            break  # stop after first found

print(f"✅ Copied {copied} image files from '{folder3}' to '{folder2}'.")
# Out:
# ✅ Copied image_021.jpg
# ✅ Copied image_982.jpg
# ✅ Copied image_1013.jpeg
# ✅ Copied image_104.jpg
# ✅ Copied image_896.jpg
# ✅ Copied image_135.jpg
# ✅ Copied image_2590.jpg
# ✅ Copied image_2569.jpg
# ✅ Copied image_983.jpeg
# ✅ Copied image_2711.jpg
# ✅ Copied image_988.jpg
# ✅ Copied image_1018.jpg
# ✅ Copied image_2558.jpg
# ✅ Copied image_2534.jpeg
# ✅ Copied image_136.jpg
# ✅ Copied image_076.jpg
# ✅ Copied image_2704.jpg
# ✅ Copied image_920.jpg
# ✅ Copied image_043.jpg
# ✅ Copied image_1051.jpeg
# ✅ Copied image_2514.jpg
# ✅ Copied image_100.jpg
# ✅ Copied image_2696.jpg
# ✅ Copied image_127.jpg
# ✅ Copied image_130.jpg
# ✅ Copied image_068.jpg
# ✅ Copied image_048.jpg
# ✅ Copied image_108.jpg
# ✅ Copied image_969.jpeg
# ✅ Copied image_033.jpg
# ✅ Copied image_138.jpg
# ✅ Copied image_995.jpeg
# ✅ Copied image_054.jpg
# ✅ Copied image_087.jpg
# ✅ Copied image_1053.jpeg
# ✅ Copied image_959.jpeg
# ✅ Copied image_973.jpeg
# ✅ Copied image_148.jpg
# ✅ Copied image_198.jpg
# ✅ Copied image_945.jpeg
# ✅ Copied image_059.jpg
# ✅ Copied image_1047.jpeg
# ✅ Copied image_064.jpg
# ✅ Copied image_035.jpg
# ✅ Copied image_211.jpg
# ✅ Copied image_2588.jpg
# ✅ Copied image_2624.jpg
# ✅ Copied image_1072.jpg
# ✅ Copied image_027.jpg
# ✅ Copied image_913.jpeg
# ✅ Copied image_090.jpg
# ✅ Copied image_1005.jpeg
# ✅ Copied image_2600.jpg
# ✅ Copied image_1055.jpeg
# ✅ Copied image_2645.jpg
# ✅ Copied image_106.jpg
# ✅ Copied image_097.jpg
# ✅ Copied image_890.jpg
# ✅ Copied image_147.jpg
# ✅ Copied image_1074.jpg
# ✅ Copied image_2675.jpg
# ✅ Copied image_1048.jpg
# ✅ Copied image_164.jpg
# ✅ Copied image_053.jpg
# ✅ Copied image_876.jpg
# ✅ Copied image_2719.jpg
# ✅ Copied image_2706.jpg
# ✅ Copied image_911.jpeg
# ✅ Copied image_084.jpg
# ✅ Copied image_873.jpeg
# ✅ Copied image_2623.jpg
# ✅ Copied image_892.jpg
# ✅ Copied image_1060.jpg
# ✅ Copied image_918.jpg
# ✅ Copied image_095.jpg
# ✅ Copied image_118.jpg
# ✅ Copied image_1079.jpeg
# ✅ Copied image_001.jpg
# ✅ Copied image_2512.jpg
# ✅ Copied image_2776.jpg
# ✅ Copied image_2658.jpg
# ✅ Copied image_110.jpg
# ✅ Copied image_1006.jpg
# ✅ Copied image_1027.jpeg
# ✅ Copied image_1033.jpeg
# ✅ Copied image_2681.jpg
# ✅ Copied image_985.jpeg
# ✅ Copied image_079.jpg
# ✅ Copied image_2707.jpg
# ✅ Copied image_1078.jpg
# ✅ Copied image_060.jpg
# ✅ Copied image_2648.jpg
# ✅ Copied image_2601.jpg
# ✅ Copied image_998.jpg
# ✅ Copied image_140.jpg
# ✅ Copied image_036.jpg
# ✅ Copied image_103.jpg
# ✅ Copied image_185.jpg
# ✅ Copied image_1021.jpeg
# ✅ Copied image_2734.jpg
# ✅ Copied image_2626.jpg
# ✅ Copied image_1065.jpeg
# ✅ Copied image_2642.jpg
# ✅ Copied image_009.jpg
# ✅ Copied image_954.jpg
# ✅ Copied image_010.jpg
# ✅ Copied image_897.jpeg
# ✅ Copied image_166.jpg
# ✅ Copied image_1081.jpeg
# ✅ Copied image_156.jpg
# ✅ Copied image_2751.jpg
# ✅ Copied image_2650.jpg
# ✅ Copied image_183.jpg
# ✅ Copied image_216.jpg
# ✅ Copied image_908.jpg
# ✅ Copied image_052.jpg
# ✅ Copied image_1014.jpg
# ✅ Copied image_205.jpg
# ✅ Copied image_098.jpg
# ✅ Copied image_167.jpg
# ✅ Copied image_107.jpg
# ✅ Copied image_898.jpg
# ✅ Copied image_038.jpg
# ✅ Copied image_101.jpg
# ✅ Copied image_2721.jpg
# ✅ Copied image_871.jpeg
# ✅ Copied image_141.jpg
# ✅ Copied image_1077.jpeg
# ✅ Copied image_956.jpg
# ✅ Copied image_2660.jpg
# ✅ Copied image_2602.jpg
# ✅ Copied image_941.jpeg
# ✅ Copied image_073.jpg
# ✅ Copied image_182.jpg
# ✅ Copied image_925.jpeg
# ✅ Copied image_2739.jpg
# ✅ Copied image_926.jpg
# ✅ Copied image_957.jpeg
# ✅ Copied image_2561.jpg
# ✅ Copied image_169.jpg
# ✅ Copied image_188.jpg
# ✅ Copied image_088.jpg
# ✅ Copied image_963.jpeg
# ✅ Copied image_948.jpg
# ✅ Copied image_112.jpg
# ✅ Copied image_083.jpg
# ✅ Copied image_2725.jpg
# ✅ Copied image_072.jpg
# ✅ Copied image_2529.jpg
# ✅ Copied image_2630.jpg
# ✅ Copied image_075.jpg
# ✅ Copied image_2665.jpg
# ✅ Copied image_937.jpeg
# ✅ Copied image_192.jpg
# ✅ Copied image_093.jpg
# ✅ Copied image_2524.jpg
# ✅ Copied image_904.jpg
# ✅ Copied image_012.jpg
# ✅ Copied image_894.jpg
# ✅ Copied image_102.jpg
# ✅ Copied image_080.jpg
# ✅ Copied image_914.jpg
# ✅ Copied image_943.jpeg
# ✅ Copied image_2523.jpg
# ✅ Copied image_964.jpg
# ✅ Copied image_077.jpg
# ✅ Copied image_1019.jpeg
# ✅ Copied image_1054.jpg
# ✅ Copied image_133.jpg
# ✅ Copied image_066.jpg
# ✅ Copied image_109.jpg
# ✅ Copied image_2531.jpg
# ✅ Copied image_949.jpeg
# ✅ Copied image_2651.jpg
# ✅ Copied image_1036.jpg
# ✅ Copied image_171.jpg
# ✅ Copied image_1032.jpg
# ✅ Copied image_951.jpeg
# ✅ Copied image_2546.jpg
# ✅ Copied image_1004.jpg
# ✅ Copied image_996.jpg
# ✅ Copied image_886.jpg
# ✅ Copied image_2736.jpg
# ✅ Copied image_2611.jpg
# ✅ Copied image_2647.jpg
# ✅ Copied image_2586.jpg
# ✅ Copied image_2541.jpg
# ✅ Copied image_944.jpg
# ✅ Copied image_2783.jpg
# ✅ Copied image_1042.jpg
# ✅ Copied image_870.jpg
# ✅ Copied image_1037.jpeg
# ✅ Copied image_1050.jpg
# ✅ Copied image_2517.jpg
# ✅ Copied image_014.jpg
# ✅ Copied image_2702.jpg
# ✅ Copied image_869.jpeg
# ✅ Copied image_2522.jpg
# ✅ Copied image_950.jpg
# ✅ Copied image_1062.jpg
# ✅ Copied image_891.jpeg
# ✅ Copied image_1022.jpg
# ✅ Copied image_2570.jpg
# ✅ Copied image_132.jpg
# ✅ Copied image_977.jpeg
# ✅ Copied image_966.jpg
# ✅ Copied image_016.jpg
# ✅ Copied image_1063.jpeg
# ✅ Copied image_105.jpg
# ✅ Copied image_2556.jpg
# ✅ Copied image_115.jpg
# ✅ Copied image_042.jpg
# ✅ Copied image_150.jpg
# ✅ Copied image_928.jpg
# ✅ Copied image_2540.jpg
# ✅ Copied image_2613.jpg
# ✅ Copied image_953.jpeg
# ✅ Copied image_2693.jpg
# ✅ Copied image_2574.jpg
# ✅ Copied image_199.jpg
# ✅ Copied image_2616.jpg
# ✅ Copied image_005.jpg
# ✅ Copied image_069.jpg
# ✅ Copied image_902.jpg
# ✅ Copied image_2726.jpg
# ✅ Copied image_1039.jpeg
# ✅ Copied image_020.jpg
# ✅ Copied image_019.jpg
# ✅ Copied image_2679.jpg
# ✅ Copied image_134.jpg
# ✅ Copied image_2703.jpg
# ✅ Copied image_184.jpg
# ✅ Copied image_2777.jpg
# ✅ Copied image_2774.jpg
# ✅ Copied image_940.jpg
# ✅ Copied image_1076.jpg
# ✅ Copied image_2697.jpg
# ✅ Copied image_2715.jpg
# ✅ Copied image_017.jpg
# ✅ Copied image_029.jpg
# ✅ Copied image_200.jpg
# ✅ Copied image_885.jpeg
# ✅ Copied image_990.jpg
# ✅ Copied image_932.jpg
# ✅ Copied image_139.jpg
# ✅ Copied image_2683.jpg
# ✅ Copied image_2764.jpg
# ✅ Copied image_2539.jpg
# ✅ Copied image_2708.jpg
# ✅ Copied image_215.jpg
# ✅ Copied image_2553.jpg
# ✅ Copied image_2720.jpg
# ✅ Copied image_917.jpeg
# ✅ Copied image_2595.jpg
# ✅ Copied image_074.jpg
# ✅ Copied image_906.jpg
# ✅ Copied image_045.jpg
# ✅ Copied image_901.jpeg
# ✅ Copied image_1025.jpeg
# ✅ Copied image_028.jpg
# ✅ Copied image_946.jpg
# ✅ Copied image_172.jpg
# ✅ Copied image_1002.jpg
# ✅ Copied image_2691.jpg
# ✅ Copied image_1075.jpeg
# ✅ Copied image_895.jpeg
# ✅ Copied image_2754.jpg
# ✅ Copied image_936.jpg
# ✅ Copied image_2657.jpg
# ✅ Copied image_1061.jpeg
# ✅ Copied image_063.jpg
# ✅ Copied image_981.jpeg
# ✅ Copied image_1056.jpg
# ✅ Copied image_180.jpg
# ✅ Copied image_2710.jpg
# ✅ Copied image_2718.jpg
# ✅ Copied image_194.jpg
# ✅ Copied image_970.jpg
# ✅ Copied image_975.jpeg
# ✅ Copied image_1009.jpeg
# ✅ Copied image_018.jpg
# ✅ Copied image_006.jpg
# ✅ Copied image_085.jpg
# ✅ Copied image_2735.jpg
# ✅ Copied image_887.jpeg
# ✅ Copied image_2741.jpg
# ✅ Copied image_2579.jpg
# ✅ Copied image_144.jpg
# ✅ Copied image_157.jpg
# ✅ Copied image_114.jpg
# ✅ Copied image_174.jpg
# ✅ Copied image_197.jpg
# ✅ Copied image_2687.jpg
# ✅ Copied image_179.jpg
# ✅ Copied image_177.jpg
# ✅ Copied image_2646.jpeg
# ✅ Copied image_997.jpeg
# ✅ Copied image_195.jpg
# ✅ Copied image_152.jpg
# ✅ Copied image_2729.jpg
# ✅ Copied image_2607.jpg
# ✅ Copied image_2690.jpg
# ✅ Copied image_919.jpeg
# ✅ Copied image_204.jpg
# ✅ Copied image_1073.jpeg
# ✅ Copied image_976.jpg
# ✅ Copied image_922.jpg
# ✅ Copied image_984.jpg
# ✅ Copied image_178.jpg
# ✅ Copied image_071.jpg
# ✅ Copied image_967.jpeg
# ✅ Copied image_992.jpg
# ✅ Copied image_2784.jpg
# ✅ Copied image_146.jpg
# ✅ Copied image_2674.jpg
# ✅ Copied image_122.jpg
# ✅ Copied image_2666.jpg
# ✅ Copied image_2580.jpg
# ✅ Copied image_965.jpeg
# ✅ Copied image_2750.jpg
# ✅ Copied image_2527.jpg
# ✅ Copied image_2510.jpg
# ✅ Copied image_915.jpeg
# ✅ Copied image_1057.jpeg
# ✅ Copied image_2598.jpg
# ✅ Copied image_2740.jpg
# ✅ Copied image_2758.jpeg
# ✅ Copied image_927.jpeg
# ✅ Copied image_1041.jpeg
# ✅ Copied image_082.jpg
# ✅ Copied image_2752.jpg
# ✅ Copied image_2673.jpg
# ✅ Copied image_1068.jpg
# ✅ Copied image_124.jpg
# ✅ Copied image_1020.jpg
# ✅ Copied image_2532.jpg
# ✅ Copied image_2625.jpg
# ✅ Copied image_008.jpg
# ✅ Copied image_1040.jpg
# ✅ Copied image_026.jpg
# ✅ Copied image_1038.jpg
# ✅ Copied image_2672.jpg
# ✅ Copied image_119.jpg
# ✅ Copied image_2543.jpg
# ✅ Copied image_203.jpg
# ✅ Copied image_874.jpg
# ✅ Copied image_2737.jpg
# ✅ Copied image_015.jpg
# ✅ Copied image_2749.jpg
# ✅ Copied image_158.jpg
# ✅ Copied image_047.jpg
# ✅ Copied image_881.jpeg
# ✅ Copied image_905.jpeg
# ✅ Copied image_004.jpg
# ✅ Copied image_170.jpg
# ✅ Copied image_2593.jpg
# ✅ Copied image_1059.jpeg
# ✅ Copied image_888.jpg
# ✅ Copied image_209.jpg
# ✅ Copied image_154.jpg
# ✅ Copied image_2743.jpg
# ✅ Copied image_2612.jpg
# ✅ Copied image_2557.jpg
# ✅ Copied image_1010.jpg
# ✅ Copied image_2583.jpg
# ✅ Copied image_128.jpg
# ✅ Copied image_1043.jpeg
# ✅ Copied image_2544.jpg
# ✅ Copied image_031.jpg
# ✅ Copied image_2542.jpg
# ✅ Copied image_193.jpg
# ✅ Copied image_142.jpg
# ✅ Copied image_2605.jpg
# ✅ Copied image_910.jpg
# ✅ Copied image_187.jpg
# ✅ Copied image_173.jpg
# ✅ Copied image_2722.jpg
# ✅ Copied image_207.jpg
# ✅ Copied image_923.jpeg
# ✅ Copied image_1064.jpg
# ✅ Copied image_1080.jpg
# ✅ Copied image_2716.jpg
# ✅ Copied image_096.jpg
# ✅ Copied image_2637.jpg
# ✅ Copied image_1049.jpeg
# ✅ Copied image_991.jpeg
# ✅ Copied image_916.jpg
# ✅ Copied image_1034.jpg
# ✅ Copied image_2723.jpg
# ✅ Copied image_120.jpg
# ✅ Copied image_2629.jpg
# ✅ Copied image_2701.jpg
# ✅ Copied image_986.jpg
# ✅ Copied image_007.jpg
# ✅ Copied image_155.jpg
# ✅ Copied image_213.jpg
# ✅ Copied image_2587.jpg
# ✅ Copied image_939.jpeg
# ✅ Copied image_058.jpg
# ✅ Copied image_955.jpeg
# ✅ Copied image_900.jpg
# ✅ Copied image_2643.jpg
# ✅ Copied image_1003.jpeg
# ✅ Copied image_1015.jpeg
# ✅ Copied image_2667.jpg
# ✅ Copied image_190.jpg
# ✅ Copied image_023.jpg
# ✅ Copied image_968.jpg
# ✅ Copied image_2519.jpg
# ✅ Copied image_961.jpeg
# ✅ Copied image_113.jpg
# ✅ Copied image_065.jpg
# ✅ Copied image_206.jpg
# ✅ Copied image_2676.jpg
# ✅ Copied image_022.jpg
# ✅ Copied image_165.jpg
# ✅ Copied image_2592.jpg
# ✅ Copied image_2727.jpg
# ✅ Copied image_875.jpeg
# ✅ Copied image_044.jpg
# ✅ Copied image_032.jpg
# ✅ Copied image_2644.jpg
# ✅ Copied image_2759.jpg
# ✅ Copied image_2599.jpg
# ✅ Copied image_189.jpg
# ✅ Copied image_931.jpeg
# ✅ Copied image_131.jpg
# ✅ Copied image_030.jpg
# ✅ Copied image_1023.jpeg
# ✅ Copied image_092.jpg
# ✅ Copied image_123.jpg
# ✅ Copied image_1024.jpg
# ✅ Copied image_191.jpg
# ✅ Copied image_893.jpeg
# ✅ Copied image_159.jpg
# ✅ Copied image_168.jpg
# ✅ Copied image_938.jpg
# ✅ Copied image_989.jpeg
# ✅ Copied image_099.jpg
# ✅ Copied image_942.jpg
# ✅ Copied image_2565.jpg
# ✅ Copied image_958.jpg
# ✅ Copied image_2640.jpg
# ✅ Copied image_1029.jpeg
# ✅ Copied image_1044.jpg
# ✅ Copied image_210.jpg
# ✅ Copied image_930.jpg
# ✅ Copied image_040.jpg
# ✅ Copied image_1031.jpeg
# ✅ Copied image_186.jpg
# ✅ Copied image_2631.jpg
# ✅ Copied image_2516.jpg
# ✅ Copied image_061.jpg
# ✅ Copied image_137.jpg
# ✅ Copied image_111.jpg
# ✅ Copied image_2525.jpg
# ✅ Copied image_1066.jpg
# ✅ Copied image_2547.jpg
# ✅ Copied image_051.jpg
# ✅ Copied image_050.jpg
# ✅ Copied image_921.jpeg
# ✅ Copied image_037.jpg
# ✅ Copied image_907.jpeg
# ✅ Copied image_1046.jpg
# ✅ Copied image_121.jpg
# ✅ Copied image_086.jpg
# ✅ Copied image_149.jpg
# ✅ Copied image_880.jpg
# ✅ Copied image_878.jpg
# ✅ Copied image_181.jpg
# ✅ Copied image_2597.jpg
# ✅ Copied image_175.jpg
# ✅ Copied image_987.jpeg
# ✅ Copied image_909.jpeg
# ✅ Copied image_872.jpg
# ✅ Copied image_117.jpg
# ✅ Copied image_2678.jpg
# ✅ Copied image_2633.jpg
# ✅ Copied image_2636.jpg
# ✅ Copied image_003.jpg
# ✅ Copied image_2564.jpg
# ✅ Copied image_1045.jpeg
# ✅ Copied image_2528.jpg
# ✅ Copied image_1017.jpeg
# ✅ Copied image_978.jpg
# ✅ Copied image_1001.jpeg
# ✅ Copied image_912.jpg
# ✅ Copied image_024.jpg
# ✅ Copied image_129.jpg
# ✅ Copied image_2526.jpg
# ✅ Copied image_062.jpg
# ✅ Copied image_2635.jpg
# ✅ Copied image_057.jpg
# ✅ Copied image_1008.jpg
# ✅ Copied image_2585.jpg
# ✅ Copied image_877.jpeg
# ✅ Copied image_879.jpeg
# ✅ Copied image_2533.jpg
# ✅ Copied image_2760.jpg
# ✅ Copied image_125.jpg
# ✅ Copied image_972.jpg
# ✅ Copied image_929.jpeg
# ✅ Copied image_201.jpg
# ✅ Copied image_081.jpg
# ✅ Copied image_002.jpg
# ✅ Copied image_935.jpeg
# ✅ Copied image_1052.jpg
# ✅ Copied image_2554.jpg
# ✅ Copied image_2661.jpg
# ✅ Copied image_055.jpg
# ✅ Copied image_089.jpg
# ✅ Copied 601 image files from 'dataset' to 'dataset_object_detection/images'.
